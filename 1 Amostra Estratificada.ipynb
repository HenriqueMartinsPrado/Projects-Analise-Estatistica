# %% [markdown]
# # Amostragem Estratificada

# %% [markdown]
# #### Bibliotecas

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Setup Jupyter Notebook

# %%
# Ajustando a largura do jupyter notebook
from IPython.core.display import display, HTML 
display(HTML("<style>.container {width:90% !important;}</style>"))

# Ajustando quantidade de linhas e colunas do data frame
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 2000)
# Out:
# <style>.container {width:90% !important;}</style>

# %% [markdown]
# #### Importando os dados

# %%
iris = pd.read_csv(r'C:\Users\Henrique.HENRIQUE\Documents\Jornada do Conhecimento\Udemy\Formação Cientista de Dados\Estatística I\Dados\iris.csv')
iris
# Out:
#      sepal length  sepal width  petal length  petal width            class
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 5             5.4          3.9           1.7          0.4      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# ...

# %%
# Deixando explicito a quantidade de linhas e colunas importadas do meu dataset
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# #### Fazendo a contagem de um atributo chamado no dataset de "class"

# %%
# Contagem de valores no atributo chamado no dataset de class
iris['class'].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: class, dtype: int64

# %% [markdown]
# #### Divisão do meu dataset

# %%
# Divisão do meu dataset mutilizando a função train_test_split
X, _, y, _ = train_test_split(iris.iloc[:, 0:4], iris.iloc[:, 4], test_size = 0.5, stratify = iris.iloc[:, 4])

# %%
# Verificando quantos valores foram retornados de cada uma
y.value_counts()
# Out:
# Iris-setosa        25
# Iris-versicolor    25
# Iris-virginica     25
# Name: class, dtype: int64

# %% [markdown]
# #### Trabalhando com o dataset infert

# %%
infert = pd.read_csv(r'C:\Users\Henrique.HENRIQUE\Documents\Jornada do Conhecimento\Udemy\Formação Cientista de Dados\Estatística I\Dados\infert.csv')
infert
# Out:
#      Unnamed: 0 education  age  parity  induced  case  spontaneous  stratum  \
# 0             1    0-5yrs   26       6        1     1            2        1
# 1             2    0-5yrs   42       1        1     1            0        2
# 2             3    0-5yrs   39       6        2     1            0        3
# 3             4    0-5yrs   34       4        2     1            0        4
# 4             5   6-11yrs   35       3        1     1            1        5
# 5             6   6-11yrs   36       4        2     1            1        6
# 6             7   6-11yrs   23       1        0     1            0        7
# 7             8   6-11yrs   32       2        0     1            0        8
# 8             9   6-11yrs   21       1        0     1            1        9
# 9            10   6-11yrs   28       2        0     1            0       10
# 10           11   6-11yrs   29       2        1     1            0       11
# ...

# %% [markdown]
# #### Analisando o atributo "education"

# %%
infert['education'].value_counts()
# Out:
# 6-11yrs    120
# 12+ yrs    116
# 0-5yrs      12
# Name: education, dtype: int64

# %%
infert.shape
# Out:
# (248, 9)

# %%
# Porcentagem de registros que representam de 6-11yrs
(120 / 248) * 100
# Out:
# 48.38709677419355

# %%
# Porcentagem de registros que representam de 12+ yrs
(116 / 248) * 100
# Out:
# 46.774193548387096

# %%
# Porcentagem de registros que representam de 0-5yrs
(12 / 248) * 100
# Out:
# 4.838709677419355

# %% [markdown]
# #### Dividindo a minha base dados

# %%
# Divisão do meu dataset mutilizando a função train_test_split
# Importante: Coloco o _ para não trazer o complemento dos dados do meu dataset
X1, _, y1, _ = train_test_split(infert.iloc[:, 2:9], infert.iloc[:, 1], test_size = 0.6, stratify = infert.iloc[:, 1])

# %%
y1.value_counts()
# Out:
# 6-11yrs    48
# 12+ yrs    46
# 0-5yrs      5
# Name: education, dtype: int64
